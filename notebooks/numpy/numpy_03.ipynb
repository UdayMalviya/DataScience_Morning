# %%
import numpy as np

# %%
arr = np.array([1,2,3])

# %%
arr
# Out:
# array([1, 2, 3])

# %%
np.sum(arr)
# Out:
# np.int64(6)

# %%
np.prod(arr)
# Out:
# np.int64(6)

# %%
np.add(arr, arr)
# Out:
# array([2, 4, 6])

# %%
arr + arr
# Out:
# array([2, 4, 6])

# %%
arr = np.arange(0, 6).reshape(2,3)
arr2 = np.arange(0, 6).reshape(3,2)

# %%
arr, arr2
# Out:
# (array([[0, 1, 2],
#         [3, 4, 5]]),
#  array([[0, 1],
#         [2, 3],
#         [4, 5]]))

# %%
np.multiply(arr, arr2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1381149204.py in <cell line: 0>()
# ----> 1 np.multiply(arr, arr2)
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)

# %%
np.matmul(arr, arr2)
# Out:
# array([[10, 13],
#        [28, 40]])

# %%
arr @ arr2
# Out:
# array([[10, 13],
#        [28, 40]])

# %%
np.dot(arr, arr2) * (arr@arr2)
# Out:
# array([[ 100,  169],
#        [ 784, 1600]])

# %%
arr[0]
# Out:
# array([0, 1, 2])

# %%
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.add(arr[:, 0], arr[:,1])
# Out:
# array([1, 7])

# %%
arr[:, 0]
# Out:
# array([0, 3])

# %%
arr[:, 1]
# Out:
# array([1, 4])

# %%
arr.ndim
# Out:
# 2

# %%
np.sum(arr, axis=0)
# Out:
# array([3, 5, 7])

# %%
np.sum(arr, axis=1)
# Out:
# array([ 3, 12])

# %%
a = np.linspace(3,5, 30).reshape(3,5,2)

# %%
np.sum(a, axis=2)
# Out:
# array([[6.06896552, 6.34482759, 6.62068966, 6.89655172, 7.17241379],
#        [7.44827586, 7.72413793, 8.        , 8.27586207, 8.55172414],
#        [8.82758621, 9.10344828, 9.37931034, 9.65517241, 9.93103448]])

# %%
a
# Out:
# array([[[3.        , 3.06896552],
#         [3.13793103, 3.20689655],
#         [3.27586207, 3.34482759],
#         [3.4137931 , 3.48275862],
#         [3.55172414, 3.62068966]],
#
#        [[3.68965517, 3.75862069],
#         [3.82758621, 3.89655172],
#         [3.96551724, 4.03448276],
#         [4.10344828, 4.17241379],
#         [4.24137931, 4.31034483]],
#
#        [[4.37931034, 4.44827586],
#         [4.51724138, 4.5862069 ],
#         [4.65517241, 4.72413793],
#         [4.79310345, 4.86206897],
#         [4.93103448, 5.        ]]])

# %%
np.positive(a)
# Out:
# array([[[3.        , 3.06896552],
#         [3.13793103, 3.20689655],
#         [3.27586207, 3.34482759],
#         [3.4137931 , 3.48275862],
#         [3.55172414, 3.62068966]],
#
#        [[3.68965517, 3.75862069],
#         [3.82758621, 3.89655172],
#         [3.96551724, 4.03448276],
#         [4.10344828, 4.17241379],
#         [4.24137931, 4.31034483]],
#
#        [[4.37931034, 4.44827586],
#         [4.51724138, 4.5862069 ],
#         [4.65517241, 4.72413793],
#         [4.79310345, 4.86206897],
#         [4.93103448, 5.        ]]])

# %%
a** a
# Out:
# array([[[  27.        ,   31.22925918],
#         [  36.17701421,   41.97223378],
#         [  48.76807468,   56.74658605],
#         [  66.1243574 ,   77.15930535],
#         [  90.15883438,  105.48965781]],
#
#        [[ 123.58962517,  144.98197694],
#         [ 170.29253735,  200.27046614],
#         [ 235.81332436,  277.99737306],
#         [ 328.11422348,  387.71520206],
#         [ 458.6650923 ,  543.20728087]],
#
#        [[ 644.04278334,  764.42617287],
#         [ 908.28210718, 1080.34697339],
#         [1286.34118122, 1533.17887681],
#         [1829.22337451, 2184.59847887],
#         [2611.56817461, 3125.        ]]])

# %%
np.power(a, a)
# Out:
# array([[[  27.        ,   31.22925918],
#         [  36.17701421,   41.97223378],
#         [  48.76807468,   56.74658605],
#         [  66.1243574 ,   77.15930535],
#         [  90.15883438,  105.48965781]],
#
#        [[ 123.58962517,  144.98197694],
#         [ 170.29253735,  200.27046614],
#         [ 235.81332436,  277.99737306],
#         [ 328.11422348,  387.71520206],
#         [ 458.6650923 ,  543.20728087]],
#
#        [[ 644.04278334,  764.42617287],
#         [ 908.28210718, 1080.34697339],
#         [1286.34118122, 1533.17887681],
#         [1829.22337451, 2184.59847887],
#         [2611.56817461, 3125.        ]]])

# %%
np.divmod(arr, 5)
# Out:
# (array([[0, 0, 0],
#         [0, 0, 1]]),
#  array([[0, 1, 2],
#         [3, 4, 0]]))

# %%
np.sign(arr)
# Out:
# array([[0, 1, 1],
#        [1, 1, 1]])

# %%
np.log(2)
# Out:
# np.float64(0.6931471805599453)

# %%
np.log2(2)
# Out:
# np.float64(1.0)

# %%
truth=np.equal(arr, arr)
falsy = np.less(arr, arr)

# %%
np.logical_or(truth, falsy)
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True]])

# %%
1.2
# Out:
# 1.2

# %%
np.inf
# Out:
# inf

# %%
np.nan
# Out:
# nan

# %%
np.trunc(np.array(['INF', 'inf', 'nan', 7.65656], dtype=np.float64))
# Out:
# array([inf, inf, nan,  7.])

# %%
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
view copy

# %%
view
shallow copy
deep copy

# %%
view = arr

# %%
view[0,0] = 4

# %%
arr
# Out:
# array([[4, 1, 2],
#        [3, 4, 5]])

# %%
shallow = arr.copy()

# %%
shallow[0] = 90

# %%
arr
# Out:
# array([[100, 100, 100],
#        [  3,   4,   5]])

# %%
id(arr)
# Out:
# 140631935156944

# %%
id(shallow)
# Out:
# 140631935168848

# %%
id(arr), id(shallow)
# Out:
# (140631935156944, 140631935166928)

# %%
id(arr[0,0]), id(shallow[0,0])
# Out:
# (140631935815312, 140631935815312)

# %%
shallow
# Out:
# array([[90, 90, 90],
#        [ 3,  4,  5]])

# %%
arr[0] = 100

# %%
shallow
# Out:
# array([[90, 90, 90],
#        [ 3,  4,  5]])

# %%
arr
# Out:
# array([[100, 100, 100],
#        [  3,   4,   5]])

# %%
id(arr[0,2])
# Out:
# 140631935818320

# %%
id(shallow[0,2])
# Out:
# 140631935817392

# %%
import copy

# %%
s = copy.copy(arr)

# %%
id(s), id(arr)
# Out:
# (140631935168944, 140631935156944)

# %%
id(s[0]), id(arr[0])
# Out:
# (140631935170576, 140631935170576)

# %%
id(s[0,0]),  id(arr[0,0])
# Out:
# (140631935821936, 140631935821936)

# %%
s[0,0] = 8

# %%
s
# Out:
# array([[  8, 100, 100],
#        [  3,   4,   5]])

# %%
arr
# Out:
# array([[100, 100, 100],
#        [  3,   4,   5]])

# %%
import copy

# %%
copy.deepcopy()
