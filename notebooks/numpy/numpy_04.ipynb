# %%
import numpy as np

# %%
# sum, mean, median,

# %%
arr = np.array([1,2,3])

# %%
arr
# Out:
# array([1, 2, 3])

# %%
np.sum(arr)
# Out:
# np.int64(6)

# %%
np.mean(arr)
# Out:
# np.float64(2.0)

# %%
np.median(arr)
# Out:
# np.float64(2.0)

# %%
np.std(arr)
# Out:
# np.float64(0.816496580927726)

# %%
np.var(arr)
# Out:
# np.float64(0.6666666666666666)

# %%
np.prod(arr)
# Out:
# np.int64(6)

# %%
arr.sum()
# Out:
# np.int64(6)

# %%
arr.mean()
# Out:
# np.float64(2.0)

# %%
arr = np.array([[1,2,3], [6,7,0]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [6, 7, 0]])

# %%
np.sum(arr, axis=1)
# Out:
# array([ 6, 13])

# %%
np.mean(arr, axis=1)
# Out:
# array([2.        , 4.33333333])

# %%
np.std(arr, axis=0)
# Out:
# array([2.5, 2.5, 1.5])

# %%
np.var(arr, axis=0)
# Out:
# array([6.25, 6.25, 2.25])

# %%
# concat, stacking

# %%
arr
# Out:
# array([[1, 2, 3],
#        [6, 7, 0]])

# %%
arr2 = np.arange(0, 6).reshape(2,3)

# %%
arr2
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.concatenate([arr, arr2])
# Out:
# array([[1, 2, 3],
#        [6, 7, 0],
#        [0, 1, 2],
#        [3, 4, 5]])

# %%
# stacking

# %%
np.vstack([arr, arr2])
# Out:
# array([[1, 2, 3],
#        [6, 7, 0],
#        [0, 1, 2],
#        [3, 4, 5]])

# %%
np.hstack([arr, arr2])
# Out:
# array([[1, 2, 3, 0, 1, 2],
#        [6, 7, 0, 3, 4, 5]])

# %% [markdown]
# ## spliting an array
# ### np.array_split, np.split

# %% [markdown]
# - sum
# - mean
# - prod
# - std
# - var

# %%
def func(a, b, axis=None):
    # print(np.sum(a, axis=axis))
    print(np.concatenate([a,b]))
    print(np.stack([a,b], axis=1))

# %%
func(np.array([1,2,3]), np.array([6,7, 8]))
# Out:
# [1 2 3 6 7 8]
# [[1 6]
#  [2 7]
#  [3 8]]

# %%
arr * 3
# Out:
# array([[ 3,  6,  9],
#        [18, 21,  0]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [6, 7, 0]])

# %%
3
# Out:
# 3

# %%
arr * 3
# Out:
# array([[ 3,  6,  9],
#        [18, 21,  0]])

# %%
# broadcasting

# %%
arr
# Out:
# array([[1, 2, 3],
#        [6, 7, 0]])

# %%
a = arr.copy()

# %%
a[:] = 3

# %%
arr*a
# Out:
# array([[ 3,  6,  9],
#        [18, 21,  0]])

# %%
arr  * np.array([[2,3, 7]])
# Out:
# array([[ 2,  6, 21],
#        [12, 21,  0]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [6, 7, 0]])

# %%
np.array([[2,3, 7]]).shape
# Out:
# (1, 3)

# %%
np.array([[2], [3]]).shape
# Out:
# (2, 1)

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr + np.array([2, 3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 arr + np.array([2, 3])
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,)

# %%
arr (40, 6)
