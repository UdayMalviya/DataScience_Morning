# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.2'

# %%
lst = list(range(500000))

# %%
# %%timeit
# lst * 2

l = []
for i in lst:
    l.append(i*2)
# Out:
# 52.3 ms ± 3.12 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
arr = np.array(lst) # create numpy array from list

# %%
arr
# Out:
# array([     0,      1,      2, ..., 499997, 499998, 499999],
#       shape=(500000,))

# %%
# %%timeit
arr*2
# Out:
# 1.79 ms ± 22.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
np.array([1,2,3]) # int64
np.array([1,2,3.6]).dtype # upcasting
# Out:
# dtype('float64')

# %%
np.iinfo(np.int64)
np.finfo(np.float16)
# Out:
# finfo(resolution=0.001, min=-6.55040e+04, max=6.55040e+04, dtype=float16)

# %%
np.array(['A', 'Baa', 'C55555'])
# Out:
# array(['A', 'Baa', 'C55555'], dtype='<U6')

# %%
np.array([True, False]).dtype
# Out:
# dtype('bool')

# %%
np.array([complex('2+3j')])
# Out:
# array([2.+3.j])

# %% [markdown]
# ### 2D array

# %%
np.array([[1,3], [4,5]])
# Out:
# array([[1, 3],
#        [4, 5]])

# %%
# range(start, stop, step) # AP 
arr = np.arange(0.0, 10.5, 0.5)

# %%
print(arr)
arr.shape # prints shape of array
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10. ]
# (21,)

# %%
np.ones((2,4), dtype=np.int64) # create an array with all elemets 1
# Out:
# array([[1, 1, 1, 1],
#        [1, 1, 1, 1]])

# %%
np.array([3456565689048, 3498558745897344]),
# Out:
# (array([   3456565689048, 3498558745897344]),)

# %%
np.array([3456565689048, 3498558745897344]).astype(np.int32)
# Out:
# array([ -882984232, -1354339968], dtype=int32)

# %%
np.array([127], dtype=np.int8)+1
# Out:
# array([-128], dtype=int8)

# %%
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.zeros((3,))
# Out:
# array([0., 0., 0.])
