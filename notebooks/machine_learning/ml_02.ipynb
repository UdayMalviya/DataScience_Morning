# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,90])

# %%
import seaborn as sns

# %%
sns.kdeplot(arr)
# Out:
# <Axes: ylabel='Density'>

# %%
arr.mean()
# Out:
# np.float64(17.5)

# %%
np.abs(arr - arr.mean() / arr.std())
# Out:
# array([ 0.4606868,  1.4606868,  2.4606868,  3.4606868,  4.4606868,
#        89.4606868])

# %%
 + 1  : one std above mean

# %%
z = x - u / s

# %%
3 extreme outlers

# %%
arr
# Out:
# array([ 1,  2,  3,  4,  5, 90])

# %%
sns.scatterplot(arr)
# Out:
# <Axes: >

# %%
# imputation -> filling missing values 
from sklearn.impute import SimpleImputer

# %%
imputer  = SimpleImputer(add_indicator=True, keep_empty_features=True)

# %%
# dir(imputer)

import pandas as pd
df = pd.read_csv("../../data/titanic/train.csv")

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
imputer.fit(df[['Age']])
# Out:
# SimpleImputer(add_indicator=True, keep_empty_features=True)

# %%
imputer.transform(df[['Age']])
# Out:
# array([[22.        ,  0.        ],
#        [38.        ,  0.        ],
#        [26.        ,  0.        ],
#        ...,
#        [29.69911765,  1.        ],
#        [26.        ,  0.        ],
#        [32.        ,  0.        ]], shape=(891, 2))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
# train- test split

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = df.sample(100 )

# %%
data
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 533          534         1       3   Peter, Mrs. Catherine (Catherine Rizk)
# 184          185         1       3      Kink-Heilmann, Miss. Luise Gretchen
# 753          754         0       3                       Jonkoff, Mr. Lalio
# 282          283         0       3                de Pelsmaeker, Mr. Alfons
# 605          606         0       3            Lindell, Mr. Edvard Bengtsson
# ..           ...       ...     ...                                      ...
# 309          310         1       1           Francatelli, Miss. Laura Mabel
# 789          790         0       1                 Guggenheim, Mr. Benjamin
# 429          430         1       3       Pickard, Mr. Berk (Berk Trembisky)
# 472          473         1       2  West, Mrs. Edwy Arthur (Ada Mary Worth)
# 512          513         1       1                McGough, Mr. James Robert
#
# ...

# %%
# data, df
df[df.isin(data).notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop(data.index)

# %%
imputer = SimpleImputer(keep_empty_features=True, strategy='constant')
imputer.fit(df)
# Out:
# SimpleImputer(keep_empty_features=True, strategy='constant')

# %%
imputer.transform(data)
# Out:
# array([[534, 1, 3, ..., 22.3583, 'missing_value', 'C'],
#        [185, 1, 3, ..., 22.025, 'missing_value', 'S'],
#        [754, 0, 3, ..., 7.8958, 'missing_value', 'S'],
#        ...,
#        [430, 1, 3, ..., 8.05, 'E10', 'S'],
#        [473, 1, 2, ..., 27.75, 'missing_value', 'S'],
#        [513, 1, 1, ..., 26.2875, 'E25', 'S']],
#       shape=(100, 12), dtype=object)

# %%
fit, fit_transfrom, transform
# data leakage

# %%
imputer.keep_empty_features
# Out:
# True
