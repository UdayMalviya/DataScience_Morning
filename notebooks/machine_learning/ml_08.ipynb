# %%
import numpy as np
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_features=3, noise=10)

# %%
X.shape, y.shape
# Out:
# ((100, 3), (100,))

# %%
import seaborn as sns

# %%
sns.regplot(x=X, y=y)
# Out:
# <Axes: >

# %%
X = X.flatten()

# %%
numerator = np.sum((X - np.mean(X)) * (y - np.mean(y)))
denominator = np.sum((X - np.mean(X)) ** 2)

# %%
m = numerator / denominator

# %%
# y = mx + b
# b = y - mx
b = np.mean(y) - m*np.mean(X)

# %%
b,m
# Out:
# (np.float64(-0.7942255700645653), np.float64(73.97826036434296))

# %%
# Out:
# array([ 0.36299408, -0.88510118, -0.02211699])

# %%
y[:3]
# Out:
# array([ 39.76280848, -96.55687215, -10.63254472])

# %%
# y = mx + b 
X_test , y_test= make_regression(n_features=1, noise=10)
X_test = X_test.flatten()
y_pred = m * X_test + b

# %%
X_test.shape, y_pred.shape
# Out:
# ((100,), (100,))

# %%
sns.scatterplot(x= X, y= y)

sns.lineplot(x = X_test, y = y_pred)
# Out:
# <Axes: >

# %%
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.intercept_
# Out:
# np.float64(0.8151517897953631)

# %%
reg.coef_
# Out:
# array([40.70866232, 45.50947232, 92.91660622])

# %%
m
# Out:
# np.float64(73.97826036434296)

# %%
b
# Out:
# np.float64(-0.7942255700645653)

# %%
Y = MX + B 
Y = M1X1 + M2X2 + M3X3 + B

# %%
import pandas as pd

# %%
X.shape, y.shape
# Out:
# ((100, 3), (100,))

# %%
y
# Out:
# array([   5.43761714,  144.95902114,    4.54858188,   89.78381126,
#          18.45015545,  -30.91328801,  -21.78807663,   82.8803291 ,
#         168.73035351,  -14.20631273,   11.18879374,  -16.22558678,
#         103.52872902,   72.28389494,   91.10567678, -142.73974549,
#         119.87168177,   29.90085888,   57.53954792,   12.97486293,
#           9.29138063, -172.96821296, -215.1927947 , -112.17461749,
#          37.70905747,   24.95188537,   45.8841077 , -101.40083802,
#        -247.20786068,  126.1734921 ,  -77.87904126,  -85.31239119,
#        -104.12688158,  -79.34022314,  169.03750753,  -13.31851959,
#         177.84557948, -122.4897108 , -110.68057596, -124.96009672,
#         264.01108632,  -21.07103653,  -36.85250086,  -35.58641043,
#         -83.5592155 ,  163.27082222,    5.94710003,   64.46565643,
#          10.74896372,  -42.63719397,  -25.00656484,   56.0143579 ,
#          77.97819279,  -47.50023906,   61.65729892,  -37.82897655,
# ...

# %%
# np.stack((X, y.reshape( 100, 3)), axis=1)
df = pd.DataFrame(X)
df['y'] = y

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
reg
# Out:
# LinearRegression()

# %%
X_test, y_test  = make_regression(n_features=3, noise=10)

# %%
# y_pred = reg.coef_*
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y, y_pred)
# Out:
# 21482.8051857351

# %%
r2_score(y, y_pred)
# Out:
# -0.8111792755184322
